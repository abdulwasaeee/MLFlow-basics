# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_experiment("check-localhost-conn")
with mlflow.start_run():
    mlflow.log_metric("accuracy", 0.9)
    mlflow.log_metric("loss", 0.1)
# Out:
# 2025/11/06 17:17:40 INFO mlflow.tracking.fluent: Experiment with name 'check-localhost-conn' does not exist. Creating a new experiment.
# 🏃 View run enthused-smelt-845 at: http://127.0.0.1:5000/#/experiments/186012346253207846/runs/f471fcff271042dcabb4cfaeec78d9a6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/186012346253207846

# %%
with mlflow.start_run():
    mlflow.log_metric("accuracy2", 0.5)
    mlflow.log_metric("loss2", 0.4)
# Out:
# 🏃 View run amusing-roo-502 at: http://127.0.0.1:5000/#/experiments/186012346253207846/runs/398e081872b442f18bbb4e66ccf1e105
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/186012346253207846
